# %% [markdown]
# # Dữ Liệu Chứng Khoán

# %% [markdown]
# Nguyễn Nguyên Văn - $Finpros$

# %% [markdown]
# ### Import các thư viện cần thiết vào

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import keras
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Đọc dữ liệu từ file CSV

# %%
df_FPT = pd.read_csv("FPT.csv")
df_MSN = pd.read_csv("MSN.csv")
df_PNJ = pd.read_csv("PNJ.csv")
df_VIC = pd.read_csv("VIC.csv")

# %% [markdown]
# ### Xem file trước ta thấy rằng các dữ liệu

# %% [markdown]
# #### Nhận xét :
# Các dữ liệu giờ hoặc phút không biến động quá nhiều (gần như là không thay đổi) ta nên lọc dữ liệu ngày ra để giảm chiều dữ liệu, tăng hiệu suất xử lý

# %% [markdown]
# #### Xét xét sơ bộ dữ liệu xem
# Xem xét nhằm đánh giá dữ liệu xem rồi mới tiền xử lý dữ liệu

# %%
df_FPT.describe()
# Out:
#                Open          High           Low         Close        Volume  \
# count  97406.000000  97406.000000  97406.000000  97406.000000  9.740600e+04
# mean      45.071630     45.090138     45.051430     45.071631  8.044173e+03
# std        6.359803      6.364950      6.354245      6.359799  1.753203e+04
# min       30.250000     30.250000     30.220000     30.250000  1.000000e+01
# 25%       39.740000     39.740000     39.700000     39.740000  7.500000e+02
# 50%       46.950000     46.950000     46.950000     46.950000  2.960000e+03
# 75%       49.200000     49.250000     49.170000     49.200000  8.960000e+03
# max       58.400000     58.500000     58.400000     58.400000  1.255930e+06
#
#        Open Interest
# count        97406.0
# mean             0.0
# std              0.0
# min              0.0
# 25%              0.0
# 50%              0.0
# 75%              0.0
# max              0.0

# %%
df_MSN.describe()
# Out:
#                 Open           High            Low          Close  \
# count  135354.000000  135354.000000  135354.000000  135354.000000
# mean       74.878809      74.931668      74.834625      74.880759
# std        15.418074      15.426954      15.412677      15.418857
# min        46.500000      46.500000      46.400000      46.400000
# 25%        57.900000      57.900000      57.800000      57.800000
# 50%        79.100000      79.200000      79.100000      79.100000
# 75%        86.000000      86.100000      86.000000      86.000000
# max       117.800000     118.000000     117.700000     118.000000
#
#              Volume  Open Interest
# count  1.353540e+05       135354.0
# mean   5.683578e+03            0.0
# std    2.798513e+04            0.0
# min    1.000000e+01            0.0
# 25%    5.000000e+02            0.0
# 50%    2.000000e+03            0.0
# 75%    5.560000e+03            0.0
# max    3.300680e+06            0.0

# %%
df_PNJ.describe()
# Out:
#                 Open           High            Low          Close  \
# count  125309.000000  125309.000000  125309.000000  125309.000000
# mean       72.182052      72.372590      72.042287      72.179371
# std         9.900263       9.995786       9.830847       9.899401
# min        44.430000      44.530000      44.040000      44.140000
# 25%        64.600000      64.700000      64.570000      64.600000
# 50%        72.800000      73.010000      72.640000      72.830000
# 75%        80.160000      80.350000      80.060000      80.160000
# max       100.160000     100.160000     100.160000     100.160000
#
#               Volume  Open Interest
# count  125309.000000       125309.0
# mean     3031.830451            0.0
# std      7248.952968            0.0
# min         1.000000            0.0
# 25%       220.000000            0.0
# 50%      1000.000000            0.0
# 75%      3130.000000            0.0
# max    580730.000000            0.0

# %%
df_VIC.describe()
# Out:
#                 Open           High            Low          Close  \
# count  101266.000000  101266.000000  101266.000000  101266.000000
# mean      105.376460     105.418519     105.334147     105.378791
# std        11.543158      11.535584      11.552338      11.545054
# min        68.000000      68.000000      68.000000      68.000000
# 25%        95.400000      95.400000      95.300000      95.400000
# 50%       105.300000     105.300000     105.200000     105.300000
# 75%       115.800000     115.900000     115.800000     115.800000
# max       126.100000     126.500000     126.100000     126.500000
#
#              Volume  Open Interest
# count  1.012660e+05       101266.0
# mean   3.182640e+03            0.0
# std    1.469814e+04            0.0
# min    1.000000e+01            0.0
# 25%    2.300000e+02            0.0
# 50%    1.020000e+03            0.0
# 75%    3.000000e+03            0.0
# max    1.468390e+06            0.0

# %% [markdown]
# #### Nhận xét
# Sau khi xem xét dữ liệu ta thấy dữ liệu ở cột `Open`, `High`, `Low`, `Close` không có mấy sự khác biệt ta nên lấy cột `Close` làm dữ liệu chính để đánh giá vì đây là lúc chốt phiên ngày và thật sự các cột khác cũng có giá trị không quá khác biệt (gần như không đổi)

# %% [markdown]
# ##### Tạo regex lọc ngày
# Các giá trị `phút` và `giờ` thì giá gần như không đổi, ta nên lấy ngày thôi để giảm chiều dữ liệu, tăng hiệu suất xử lý

# %%
regex_time = "\d{1,2}\/\d{1,2}\/\d{4}" # regex lọc ngày

# %% [markdown]
# ##### Lọc ngày

# %%
df_MSN['Date/Time'] = df_MSN['Date/Time'].str.extract('('+regex_time+')')
df_PNJ['Date/Time'] = df_PNJ['Date/Time'].str.extract('('+regex_time+')')
df_VIC['Date/Time'] = df_VIC['Date/Time'].str.extract('('+regex_time+')')
df_FPT['Date/Time'] = df_FPT['Date/Time'].str.extract('('+regex_time+')')

# %%
df_MSN = df_MSN.drop_duplicates(subset = ["Date/Time"])
df_MSN = df_MSN.reset_index(drop=True)

df_PNJ = df_PNJ.drop_duplicates(subset = ["Date/Time"])
df_PNJ = df_PNJ.reset_index(drop=True)

df_VIC = df_VIC.drop_duplicates(subset = ["Date/Time"])
df_VIC = df_VIC.reset_index(drop=True)

df_FPT = df_FPT.drop_duplicates(subset = ["Date/Time"])
df_FPT = df_FPT.reset_index(drop=True)

# %% [markdown]
# #### Show dữ liệu để đánh giá tiếp

# %%
plt.plot(df_MSN["Date/Time"],df_MSN["Close"],label = "MSN")
plt.plot(df_FPT["Date/Time"],df_FPT["Close"], label = "FPT")
plt.plot(df_PNJ["Date/Time"],df_PNJ["Close"], label = "PNJ")
plt.plot(df_VIC["Date/Time"],df_VIC["Close"], label = "VIC")
plt.xlabel("Time")
plt.ylabel("Price")
plt.title("Close Stocks Price Chart")
plt.legend()
plt.grid(True)
plt.xticks([])
plt.show()

# %% [markdown]
# ##### Nhận xét
# Dữ liệu khá ổn, nhưng ở 1 chổ tất cả các cổ phiếu đều bị giảm giá trị, sau khi xem lại thì được biết đó là lúc dịch `Covid-19` (biến cố bất ngờ)

# %% [markdown]
# ##### Load 1 dữ liệu để xem xét
# Ta nên đi trước 1 tập dữ liệu để xử lý (chia để trị) sau đó xử lý các dữ liệu còn lại tương tự

# %%
plt.plot(df_MSN["Date/Time"],df_MSN["Close"],label = "MSN")
plt.xlabel("Time")
plt.ylabel("Price")
plt.title("Close Stocks of MSN Chart")
plt.legend()
plt.grid(True)
plt.xticks([])
plt.show()

# %% [markdown]
# ##### Lựa chọn thuật toán dự đoán
# Với dữ liệu dạng chứng khoán thế này thông thường ta nên dùng `Liner Regression`, `Logistic Regression`, `LSTM`,...
# Tuy nhiêu với dữ liệu có dữ liệu nhiễu (`Covid-19`) thì `Liner Regression` hoặc `Logistic Rgression` không có hiệu quả vậy ta dùng mô hình $Deep$ $Learning$ `LSTM`

# %% [markdown]
# ##### Chia dữ liệu ra 2 phần train và test và giảm chiều dữ liệu từ `0-10` để dễ triển khai mô hình học máy

# %%
split_MSN = round(df_MSN.index[-1]*0.85)

# %%
data_MSN  = np.array(df_MSN["Close"]).reshape(-1,1)
time_MSN  = np.array(df_MSN.index.values.reshape(-1,1))

# %%
scalter = MinMaxScaler(feature_range=(0,10))
scalter_data_MSN  = scalter.fit_transform(data_MSN)
scalter_time_MSN  = scalter.fit_transform(time_MSN)

# %%
y_train_MSN , y_test_MSN  = scalter_data_MSN [0:split_MSN], scalter_data_MSN[split_MSN :-1]
X_train_MSN , X_test_MSN   = scalter_time_MSN [0:split_MSN], scalter_time_MSN[split_MSN :-1]

# %%
y_train_MSN.shape, X_train_MSN.shape
# Out:
# ((635, 1), (635, 1))

# %%
X_train_MSN  =  np.reshape(X_train_MSN ,(X_train_MSN.shape[0],X_train_MSN.shape[1],1))

# %% [markdown]
# #### Train dữ liệu

# %%
model = keras.models.Sequential()

# %%
model.add(keras.layers.LSTM(128,input_shape = (X_train_MSN.shape[1],1)))
model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.Dense(units = 1))

# %%
model.compile(optimizer='adam',loss='mse')
model.fit(X_train_MSN,y_train_MSN,epochs=100)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 1s 2ms/step - loss: 23.9940
# Epoch 2/100
# 20/20 [==============================] - 0s 2ms/step - loss: 20.2224
# Epoch 3/100
# 20/20 [==============================] - 0s 2ms/step - loss: 17.0765
# Epoch 4/100
# 20/20 [==============================] - 0s 2ms/step - loss: 14.7439
# Epoch 5/100
# 20/20 [==============================] - 0s 2ms/step - loss: 13.3056
# Epoch 6/100
# 20/20 [==============================] - 0s 3ms/step - loss: 12.4403
# Epoch 7/100
# 20/20 [==============================] - 0s 2ms/step - loss: 11.5671
# Epoch 8/100
# 20/20 [==============================] - 0s 2ms/step - loss: 10.8395
# Epoch 9/100
# 20/20 [==============================] - 0s 2ms/step - loss: 9.8405
# Epoch 10/100
# 20/20 [==============================] - 0s 2ms/step - loss: 8.8503
# Epoch 11/100
# 20/20 [==============================] - 0s 2ms/step - loss: 7.9396
# Epoch 12/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.9553
# Epoch 13/100
# 20/20 [==============================] - 0s 2ms/step - loss: 5.9564
# Epoch 14/100
# 20/20 [==============================] - 0s 2ms/step - loss: 5.1290
# Epoch 15/100
# 20/20 [==============================] - 0s 2ms/step - loss: 4.2966
# Epoch 16/100
# 20/20 [==============================] - 0s 2ms/step - loss: 3.5940
# Epoch 17/100
# 20/20 [==============================] - 0s 2ms/step - loss: 2.9925
# Epoch 18/100
# 20/20 [==============================] - 0s 2ms/step - loss: 2.4366
# Epoch 19/100
# 20/20 [==============================] - 0s 2ms/step - loss: 2.0836
# Epoch 20/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.8086
# Epoch 21/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.6971
# Epoch 22/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.5524
# Epoch 23/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.5322
# Epoch 24/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4530
# Epoch 25/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4756
# Epoch 26/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4445
# Epoch 27/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4475
# Epoch 28/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4597
# Epoch 29/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4105
# Epoch 30/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4778
# Epoch 31/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4494
# Epoch 32/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4268
# Epoch 33/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4406
# Epoch 34/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4118
# Epoch 35/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3952
# Epoch 36/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3882
# Epoch 37/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4360
# Epoch 38/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4650
# Epoch 39/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3716
# Epoch 40/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3875
# Epoch 41/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3906
# Epoch 42/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3859
# Epoch 43/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4001
# Epoch 44/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4540
# Epoch 45/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4186
# Epoch 46/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4259
# Epoch 47/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4205
# Epoch 48/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4069
# Epoch 49/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3914
# Epoch 50/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3574
# Epoch 51/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4079
# Epoch 52/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4316
# Epoch 53/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3894
# Epoch 54/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3999
# Epoch 55/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3720
# Epoch 56/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3222
# Epoch 57/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3788
# Epoch 58/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3953
# Epoch 59/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3732
# Epoch 60/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4160
# Epoch 61/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3881
# Epoch 62/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.4127
# Epoch 63/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3458
# Epoch 64/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3827
# Epoch 65/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3633
# Epoch 66/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3866
# Epoch 67/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3284
# Epoch 68/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3382
# Epoch 69/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3743
# Epoch 70/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3389
# Epoch 71/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3542
# Epoch 72/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3742
# Epoch 73/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3385
# Epoch 74/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3441
# Epoch 75/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3686
# Epoch 76/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3432
# Epoch 77/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3583
# Epoch 78/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3193
# Epoch 79/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3430
# Epoch 80/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3627
# Epoch 81/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3617
# Epoch 82/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3707
# Epoch 83/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3568
# Epoch 84/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3839
# Epoch 85/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3695
# Epoch 86/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3902
# Epoch 87/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3574
# Epoch 88/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3107
# Epoch 89/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3157
# Epoch 90/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3685
# Epoch 91/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3118
# Epoch 92/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3204
# Epoch 93/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3051
# Epoch 94/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3428
# Epoch 95/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3306
# Epoch 96/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3194
# Epoch 97/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3690
# Epoch 98/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3346
# Epoch 99/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.2742
# Epoch 100/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3438

# %% [markdown]
# #### Độ chính xác
# Kiểm tra độ chính xác bằng dữ liệu test

# %%
loss_MSN = model.evaluate(X_test_MSN,y_test_MSN)
accuaracy_MSN = 100-loss_MSN
accuaracy_MSN
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 14.6555
# 85.34450435638428

# %% [markdown]
# Độ chính xác khoảng $86$% cho dữ liệu `MSN`

# %% [markdown]
# ### Dự đoán dữ liệu

# %%
predic_to_time_MSN = scalter_time_MSN[0:50] + 10
time_pre_MSN = time_MSN[1:51] + time_MSN[-1]

# %%
pre_MSN = []
for i in range(0,predic_to_time_MSN.shape[0]):
   pre_MSN.append(model.predict([predic_to_time_MSN])[i])
# Out:
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 998us/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 999us/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 1ms/step

# %%
time_pre_MSN = np.array(time_pre_MSN)
time_MSN = np.concatenate((time_MSN,time_pre_MSN),axis = 0)

# %%
pre_MSN = np.array(data_MSN[-1] + pre_MSN)
data_MSN = np.concatenate((data_MSN,pre_MSN),axis= 0)

# %%
plt.plot(time_pre_MSN,pre_MSN,label = "Predicted MSN")
plt.plot(df_MSN["Close"], label = "Actual MSN")
plt.xlabel("Time")
plt.ylabel("Price")
plt.title("Close Stocks of MSN Chart")
plt.legend()
plt.grid(True)
plt.xticks([])
plt.show()

# %% [markdown]
# #### Sau khi dự đoán xong ta dự đoán tương tự

# %%
split_FPT = round(df_FPT.index[-1]*0.85)
data_FPT  = np.array(df_FPT["Close"]).reshape(-1,1)
time_FPT  = np.array(df_FPT.index.values.reshape(-1,1))
scalter_data_FPT  = scalter.fit_transform(data_FPT)
scalter_time_FPT  = scalter.fit_transform(time_FPT)
y_train_FPT , y_test_FPT  = scalter_data_FPT [0:split_FPT], scalter_data_FPT[split_FPT :-1]
X_train_FPT , X_test_FPT   = scalter_time_FPT [0:split_FPT], scalter_time_FPT[split_FPT :-1]
X_train_FPT  =  np.reshape(X_train_FPT ,(X_train_FPT.shape[0],X_train_FPT.shape[1],1))
model = keras.models.Sequential()
model.add(keras.layers.LSTM(128,input_shape = (X_train_FPT.shape[1],1)))
model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.Dense(units = 1))
model.compile(optimizer='adam',loss='mse')
model.fit(X_train_FPT,y_train_FPT,epochs=100)
loss_FPT = model.evaluate(X_test_FPT,y_test_FPT)
accuaracy_FPT = 100-loss_FPT
accuaracy_FPT
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 2ms/step - loss: 23.9691
# Epoch 2/100
# 14/14 [==============================] - 0s 2ms/step - loss: 20.0666
# Epoch 3/100
# 14/14 [==============================] - 0s 2ms/step - loss: 16.1024
# Epoch 4/100
# 14/14 [==============================] - 0s 2ms/step - loss: 12.3786
# Epoch 5/100
# 14/14 [==============================] - 0s 2ms/step - loss: 8.7265
# Epoch 6/100
# 14/14 [==============================] - 0s 2ms/step - loss: 5.8134
# Epoch 7/100
# 14/14 [==============================] - 0s 2ms/step - loss: 3.6640
# Epoch 8/100
# 14/14 [==============================] - 0s 2ms/step - loss: 2.6401
# Epoch 9/100
# 14/14 [==============================] - 0s 2ms/step - loss: 2.3319
# Epoch 10/100
# 14/14 [==============================] - 0s 2ms/step - loss: 2.2517
# Epoch 11/100
# 14/14 [==============================] - 0s 2ms/step - loss: 2.1061
# Epoch 12/100
# 14/14 [==============================] - 0s 2ms/step - loss: 2.1625
# Epoch 13/100
# 14/14 [==============================] - 0s 2ms/step - loss: 2.1049
# Epoch 14/100
# 14/14 [==============================] - 0s 2ms/step - loss: 2.1856
# Epoch 15/100
# 14/14 [==============================] - 0s 2ms/step - loss: 2.0421
# Epoch 16/100
# 14/14 [==============================] - 0s 2ms/step - loss: 2.0034
# Epoch 17/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.9912
# Epoch 18/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.9432
# Epoch 19/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.9318
# Epoch 20/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.9433
# Epoch 21/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.9513
# Epoch 22/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.9095
# Epoch 23/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.8642
# Epoch 24/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.9215
# Epoch 25/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.8319
# Epoch 26/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.7890
# Epoch 27/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.7958
# Epoch 28/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.7703
# Epoch 29/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.7275
# Epoch 30/100
# 14/14 [==============================] - 0s 3ms/step - loss: 1.7386
# Epoch 31/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.7169
# Epoch 32/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.7718
# Epoch 33/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.6769
# Epoch 34/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.6654
# Epoch 35/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.7176
# Epoch 36/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.6273
# Epoch 37/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.6452
# Epoch 38/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.6627
# Epoch 39/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.6983
# Epoch 40/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.6963
# Epoch 41/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.6400
# Epoch 42/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.6143
# Epoch 43/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.5894
# Epoch 44/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.5481
# Epoch 45/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.5997
# Epoch 46/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.6239
# Epoch 47/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.6025
# Epoch 48/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.5375
# Epoch 49/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.5752
# Epoch 50/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.6134
# Epoch 51/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.5309
# Epoch 52/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.6019
# Epoch 53/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.5619
# Epoch 54/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.5317
# Epoch 55/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.4891
# Epoch 56/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.5560
# Epoch 57/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.5311
# Epoch 58/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.5017
# Epoch 59/100
# 14/14 [==============================] - 0s 3ms/step - loss: 1.5288
# Epoch 60/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.4791
# Epoch 61/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.4700
# Epoch 62/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.4414
# Epoch 63/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.4502
# Epoch 64/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.3945
# Epoch 65/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.4603
# Epoch 66/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.3721
# Epoch 67/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.3793
# Epoch 68/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.4408
# Epoch 69/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.3667
# Epoch 70/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.4097
# Epoch 71/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.3305
# Epoch 72/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.3427
# Epoch 73/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.4192
# Epoch 74/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.3300
# Epoch 75/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.3434
# Epoch 76/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.3339
# Epoch 77/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2942
# Epoch 78/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.3492
# Epoch 79/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2274
# Epoch 80/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2308
# Epoch 81/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.3449
# Epoch 82/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.3596
# Epoch 83/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2782
# Epoch 84/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2954
# Epoch 85/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2942
# Epoch 86/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.3066
# Epoch 87/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2588
# Epoch 88/100
# 14/14 [==============================] - 0s 3ms/step - loss: 1.2534
# Epoch 89/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2706
# Epoch 90/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2061
# Epoch 91/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2600
# Epoch 92/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2376
# Epoch 93/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2616
# Epoch 94/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2393
# Epoch 95/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.1889
# Epoch 96/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.1836
# Epoch 97/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2137
# Epoch 98/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2278
# Epoch 99/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2071
# Epoch 100/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2297
# 3/3 [==============================] - 0s 2ms/step - loss: 6.4490
# 93.55095481872559

# %% [markdown]
# Dữ liệu chính xác khoảng $92$% ở dữ liệu `FPT`

# %%
predic_to_time_FPT = scalter_time_FPT[0:50] + 10
time_pre_FPT = time_FPT[1:51] + time_FPT[-1]
pre_FPT = []
for i in range(0,predic_to_time_FPT.shape[0]):
   pre_FPT.append(model.predict([predic_to_time_FPT])[i])
# Out:
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step

# %%
time_pre_FPT = np.array(time_pre_FPT)
time_FPT = np.concatenate((time_FPT,time_pre_FPT),axis = 0)

# %%
pre_FPT = np.array(data_FPT[-1] + pre_FPT)
data_FPT = np.concatenate((data_FPT,pre_FPT),axis= 0)

# %%
plt.plot(time_FPT,data_FPT,label = "FPT Predicted")
plt.plot(df_FPT["Close"], label = "FPT Actual")
plt.xlabel("Time")
plt.ylabel("Price")
plt.title("Close Stocks of FPT Chart")
plt.legend()
plt.grid(True)
plt.xticks([])
plt.show()

# %%
split_PNJ = round(df_PNJ.index[-1]*0.85)
data_PNJ  = np.array(df_PNJ["Close"]).reshape(-1,1)
time_PNJ  = np.array(df_PNJ.index.values.reshape(-1,1))
scalter_data_PNJ  = scalter.fit_transform(data_PNJ)
scalter_time_PNJ  = scalter.fit_transform(time_PNJ)
y_train_PNJ , y_test_PNJ  = scalter_data_PNJ [0:split_PNJ], scalter_data_PNJ[split_PNJ :-1]
X_train_PNJ , X_test_PNJ   = scalter_time_PNJ [0:split_PNJ], scalter_time_PNJ[split_PNJ :-1]
X_train_PNJ  =  np.reshape(X_train_PNJ ,(X_train_PNJ.shape[0],X_train_PNJ.shape[1],1))
model = keras.models.Sequential()
model.add(keras.layers.LSTM(128,input_shape = (X_train_PNJ.shape[1],1)))
model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.Dense(units = 1))
model.compile(optimizer='adam',loss='mse')
model.fit(X_train_PNJ,y_train_PNJ,epochs=100)
loss_PNJ = model.evaluate(X_test_PNJ,y_test_PNJ)
accuaracy_PNJ = 100-loss_PNJ
accuaracy_PNJ
# Out:
# Epoch 1/100
# 19/19 [==============================] - 1s 2ms/step - loss: 30.9382
# Epoch 2/100
# 19/19 [==============================] - 0s 2ms/step - loss: 25.9439
# Epoch 3/100
# 19/19 [==============================] - 0s 2ms/step - loss: 21.3151
# Epoch 4/100
# 19/19 [==============================] - 0s 2ms/step - loss: 16.6553
# Epoch 5/100
# 19/19 [==============================] - 0s 2ms/step - loss: 13.0052
# Epoch 6/100
# 19/19 [==============================] - 0s 2ms/step - loss: 10.9073
# Epoch 7/100
# 19/19 [==============================] - 0s 2ms/step - loss: 10.0215
# Epoch 8/100
# 19/19 [==============================] - 0s 2ms/step - loss: 9.6953
# Epoch 9/100
# 19/19 [==============================] - 0s 2ms/step - loss: 9.2609
# Epoch 10/100
# 19/19 [==============================] - 0s 2ms/step - loss: 8.8064
# Epoch 11/100
# 19/19 [==============================] - 0s 2ms/step - loss: 8.3093
# Epoch 12/100
# 19/19 [==============================] - 0s 2ms/step - loss: 7.8895
# Epoch 13/100
# 19/19 [==============================] - 0s 2ms/step - loss: 7.4074
# Epoch 14/100
# 19/19 [==============================] - 0s 2ms/step - loss: 6.9288
# Epoch 15/100
# 19/19 [==============================] - 0s 2ms/step - loss: 6.5146
# Epoch 16/100
# 19/19 [==============================] - 0s 2ms/step - loss: 6.2421
# Epoch 17/100
# 19/19 [==============================] - 0s 2ms/step - loss: 5.8578
# Epoch 18/100
# 19/19 [==============================] - 0s 2ms/step - loss: 5.4497
# Epoch 19/100
# 19/19 [==============================] - 0s 2ms/step - loss: 5.1236
# Epoch 20/100
# 19/19 [==============================] - 0s 2ms/step - loss: 4.7976
# Epoch 21/100
# 19/19 [==============================] - 0s 2ms/step - loss: 4.6044
# Epoch 22/100
# 19/19 [==============================] - 0s 2ms/step - loss: 4.2697
# Epoch 23/100
# 19/19 [==============================] - 0s 2ms/step - loss: 4.0344
# Epoch 24/100
# 19/19 [==============================] - 0s 2ms/step - loss: 3.8728
# Epoch 25/100
# 19/19 [==============================] - 0s 2ms/step - loss: 3.7268
# Epoch 26/100
# 19/19 [==============================] - 0s 2ms/step - loss: 3.5539
# Epoch 27/100
# 19/19 [==============================] - 0s 2ms/step - loss: 3.5580
# Epoch 28/100
# 19/19 [==============================] - 0s 2ms/step - loss: 3.3919
# Epoch 29/100
# 19/19 [==============================] - 0s 2ms/step - loss: 3.3814
# Epoch 30/100
# 19/19 [==============================] - 0s 2ms/step - loss: 3.2955
# Epoch 31/100
# 19/19 [==============================] - 0s 2ms/step - loss: 3.3386
# Epoch 32/100
# 19/19 [==============================] - 0s 2ms/step - loss: 3.2339
# Epoch 33/100
# 19/19 [==============================] - 0s 2ms/step - loss: 3.1455
# Epoch 34/100
# 19/19 [==============================] - 0s 2ms/step - loss: 3.1452
# Epoch 35/100
# 19/19 [==============================] - 0s 2ms/step - loss: 3.1181
# Epoch 36/100
# 19/19 [==============================] - 0s 2ms/step - loss: 3.1641
# Epoch 37/100
# 19/19 [==============================] - 0s 2ms/step - loss: 3.1801
# Epoch 38/100
# 19/19 [==============================] - 0s 2ms/step - loss: 3.1244
# Epoch 39/100
# 19/19 [==============================] - 0s 2ms/step - loss: 3.0561
# Epoch 40/100
# 19/19 [==============================] - 0s 2ms/step - loss: 3.0710
# Epoch 41/100
# 19/19 [==============================] - 0s 2ms/step - loss: 3.1021
# Epoch 42/100
# 19/19 [==============================] - 0s 2ms/step - loss: 3.1387
# Epoch 43/100
# 19/19 [==============================] - 0s 2ms/step - loss: 3.0538
# Epoch 44/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.9636
# Epoch 45/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.9880
# Epoch 46/100
# 19/19 [==============================] - 0s 2ms/step - loss: 3.0697
# Epoch 47/100
# 19/19 [==============================] - 0s 2ms/step - loss: 3.0823
# Epoch 48/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.9998
# Epoch 49/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.9412
# Epoch 50/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.9809
# Epoch 51/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.9476
# Epoch 52/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.9917
# Epoch 53/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.9554
# Epoch 54/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.8684
# Epoch 55/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.9738
# Epoch 56/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.9455
# Epoch 57/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.8947
# Epoch 58/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.8728
# Epoch 59/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.9841
# Epoch 60/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.8310
# Epoch 61/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.9062
# Epoch 62/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.8606
# Epoch 63/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.8486
# Epoch 64/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.8337
# Epoch 65/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.8656
# Epoch 66/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.8791
# Epoch 67/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.8665
# Epoch 68/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.8277
# Epoch 69/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.8249
# Epoch 70/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.8122
# Epoch 71/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.8332
# Epoch 72/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.8497
# Epoch 73/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.7496
# Epoch 74/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.7784
# Epoch 75/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.7297
# Epoch 76/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.7841
# Epoch 77/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.8491
# Epoch 78/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.7711
# Epoch 79/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.7267
# Epoch 80/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.7380
# Epoch 81/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.8345
# Epoch 82/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.7982
# Epoch 83/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.7390
# Epoch 84/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.7264
# Epoch 85/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.7213
# Epoch 86/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.6424
# Epoch 87/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.7045
# Epoch 88/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.6697
# Epoch 89/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.7798
# Epoch 90/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.7344
# Epoch 91/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.6781
# Epoch 92/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.6365
# Epoch 93/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.6400
# Epoch 94/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.6964
# Epoch 95/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.6964
# Epoch 96/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.5403
# Epoch 97/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.6351
# Epoch 98/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.6838
# Epoch 99/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.6259
# Epoch 100/100
# 19/19 [==============================] - 0s 2ms/step - loss: 2.5527
# 4/4 [==============================] - 0s 2ms/step - loss: 3.0893
# 96.91073274612427

# %% [markdown]
# Dữ liệu chính xác khoảng $96$% ở dữ liệu `PNJ`

# %%
predic_to_time_PNJ = scalter_time_PNJ[0:50] + 10
time_pre_PNJ = time_PNJ[1:51] + time_PNJ[-1]
pre_PNJ = []
for i in range(0,predic_to_time_PNJ.shape[0]):
   pre_PNJ.append(model.predict([predic_to_time_PNJ])[i])
# Out:
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 999us/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 999us/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 999us/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step

# %%
time_pre_PNJ = np.array(time_pre_PNJ)
time_PNJ = np.concatenate((time_PNJ,time_pre_PNJ),axis = 0)

# %%
pre_PNJ = np.array(data_PNJ[-1] + pre_PNJ)
data_PNJ = np.concatenate((data_PNJ,pre_PNJ),axis= 0)

# %%
plt.plot(time_PNJ,data_PNJ,label = "PNJ Predicted")
plt.plot(df_PNJ["Close"], label = "PNJ Actual")
plt.xlabel("Time")
plt.ylabel("Price")
plt.title("Close Stocks of PNJ Chart")
plt.legend()
plt.grid(True)
plt.xticks([])
plt.show()

# %%
split_VIC = round(df_VIC.index[-1]*0.85)
data_VIC  = np.array(df_VIC["Close"]).reshape(-1,1)
time_VIC  = np.array(df_VIC.index.values.reshape(-1,1))
scalter_data_VIC  = scalter.fit_transform(data_VIC)
scalter_time_VIC  = scalter.fit_transform(time_VIC)
y_train_VIC , y_test_VIC  = scalter_data_VIC [0:split_VIC], scalter_data_VIC[split_VIC :-1]
X_train_VIC , X_test_VIC   = scalter_time_VIC [0:split_VIC], scalter_time_VIC[split_VIC :-1]
X_train_VIC  =  np.reshape(X_train_VIC ,(X_train_VIC.shape[0],X_train_VIC.shape[1],1))
model = keras.models.Sequential()
model.add(keras.layers.LSTM(128,input_shape = (X_train_VIC.shape[1],1)))
model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.Dense(units = 1))
model.compile(optimizer='adam',loss='mse')
model.fit(X_train_VIC,y_train_VIC,epochs=100)
loss_VIC = model.evaluate(X_test_VIC,y_test_VIC)
accuaracy_VIC = 100-loss_VIC
accuaracy_VIC
# Out:
# Epoch 1/100
# 15/15 [==============================] - 1s 2ms/step - loss: 43.8161
# Epoch 2/100
# 15/15 [==============================] - 0s 2ms/step - loss: 39.3505
# Epoch 3/100
# 15/15 [==============================] - 0s 2ms/step - loss: 34.6048
# Epoch 4/100
# 15/15 [==============================] - 0s 2ms/step - loss: 29.7851
# Epoch 5/100
# 15/15 [==============================] - 0s 2ms/step - loss: 25.1045
# Epoch 6/100
# 15/15 [==============================] - 0s 2ms/step - loss: 21.0201
# Epoch 7/100
# 15/15 [==============================] - 0s 2ms/step - loss: 18.0538
# Epoch 8/100
# 15/15 [==============================] - 0s 2ms/step - loss: 16.2395
# Epoch 9/100
# 15/15 [==============================] - 0s 2ms/step - loss: 15.1536
# Epoch 10/100
# 15/15 [==============================] - 0s 2ms/step - loss: 14.3490
# Epoch 11/100
# 15/15 [==============================] - 0s 2ms/step - loss: 13.6825
# Epoch 12/100
# 15/15 [==============================] - 0s 2ms/step - loss: 12.8978
# Epoch 13/100
# 15/15 [==============================] - 0s 2ms/step - loss: 12.0963
# Epoch 14/100
# 15/15 [==============================] - 0s 2ms/step - loss: 11.4380
# Epoch 15/100
# 15/15 [==============================] - 0s 2ms/step - loss: 10.4782
# Epoch 16/100
# 15/15 [==============================] - 0s 2ms/step - loss: 9.8723
# Epoch 17/100
# 15/15 [==============================] - 0s 2ms/step - loss: 9.3723
# Epoch 18/100
# 15/15 [==============================] - 0s 2ms/step - loss: 8.4346
# Epoch 19/100
# 15/15 [==============================] - 0s 2ms/step - loss: 7.8515
# Epoch 20/100
# 15/15 [==============================] - 0s 2ms/step - loss: 7.0469
# Epoch 21/100
# 15/15 [==============================] - 0s 2ms/step - loss: 6.3975
# Epoch 22/100
# 15/15 [==============================] - 0s 2ms/step - loss: 5.8601
# Epoch 23/100
# 15/15 [==============================] - 0s 2ms/step - loss: 5.3571
# Epoch 24/100
# 15/15 [==============================] - 0s 3ms/step - loss: 4.7962
# Epoch 25/100
# 15/15 [==============================] - 0s 2ms/step - loss: 4.3001
# Epoch 26/100
# 15/15 [==============================] - 0s 2ms/step - loss: 3.8873
# Epoch 27/100
# 15/15 [==============================] - 0s 2ms/step - loss: 3.5066
# Epoch 28/100
# 15/15 [==============================] - 0s 2ms/step - loss: 3.2926
# Epoch 29/100
# 15/15 [==============================] - 0s 2ms/step - loss: 2.9299
# Epoch 30/100
# 15/15 [==============================] - 0s 2ms/step - loss: 2.7068
# Epoch 31/100
# 15/15 [==============================] - 0s 2ms/step - loss: 2.5991
# Epoch 32/100
# 15/15 [==============================] - 0s 2ms/step - loss: 2.3337
# Epoch 33/100
# 15/15 [==============================] - 0s 2ms/step - loss: 2.1618
# Epoch 34/100
# 15/15 [==============================] - 0s 2ms/step - loss: 2.1017
# Epoch 35/100
# 15/15 [==============================] - 0s 2ms/step - loss: 2.0246
# Epoch 36/100
# 15/15 [==============================] - 0s 2ms/step - loss: 2.0209
# Epoch 37/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.9572
# Epoch 38/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.8548
# Epoch 39/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.7807
# Epoch 40/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.7895
# Epoch 41/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.7538
# Epoch 42/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.6916
# Epoch 43/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.6337
# Epoch 44/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.6829
# Epoch 45/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.6307
# Epoch 46/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.6225
# Epoch 47/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.5952
# Epoch 48/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.5626
# Epoch 49/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.6064
# Epoch 50/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.6044
# Epoch 51/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.5971
# Epoch 52/100
# 15/15 [==============================] - 0s 3ms/step - loss: 1.5728
# Epoch 53/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.5547
# Epoch 54/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.5271
# Epoch 55/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.5139
# Epoch 56/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.5328
# Epoch 57/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.4947
# Epoch 58/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.4867
# Epoch 59/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.4570
# Epoch 60/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.4993
# Epoch 61/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.4521
# Epoch 62/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.4605
# Epoch 63/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.4383
# Epoch 64/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.4648
# Epoch 65/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.3552
# Epoch 66/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.4013
# Epoch 67/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.4489
# Epoch 68/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.3533
# Epoch 69/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.3928
# Epoch 70/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.3396
# Epoch 71/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.4174
# Epoch 72/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.2934
# Epoch 73/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.3504
# Epoch 74/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.3936
# Epoch 75/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.3757
# Epoch 76/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.2754
# Epoch 77/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.3149
# Epoch 78/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.2412
# Epoch 79/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.2935
# Epoch 80/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.2795
# Epoch 81/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.2609
# Epoch 82/100
# 15/15 [==============================] - 0s 3ms/step - loss: 1.2690
# Epoch 83/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.2854
# Epoch 84/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.2936
# Epoch 85/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.2163
# Epoch 86/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.2882
# Epoch 87/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.2224
# Epoch 88/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.1853
# Epoch 89/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.2779
# Epoch 90/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.2818
# Epoch 91/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.2006
# Epoch 92/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.1629
# Epoch 93/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.2218
# Epoch 94/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.1828
# Epoch 95/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.2078
# Epoch 96/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.2001
# Epoch 97/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.2200
# Epoch 98/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.2591
# Epoch 99/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.2126
# Epoch 100/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.2173
# 3/3 [==============================] - 0s 2ms/step - loss: 11.0075
# 88.99254608154297

# %% [markdown]
# Dữ liệu chính xác khoảng $87$% ở dữ liệu `VIC`

# %%
predic_to_time_VIC = scalter_time_VIC[0:50] + 10
time_pre_VIC = time_VIC[1:51] + time_VIC[-1]
pre_VIC = []
for i in range(0,predic_to_time_VIC.shape[0]):
   pre_VIC.append(model.predict([predic_to_time_VIC])[i])
# Out:
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 999us/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step

# %%
   
time_pre_VIC = np.array(time_pre_VIC)
time_VIC = np.concatenate((time_VIC,time_pre_VIC),axis = 0)

# %%
pre_VIC = np.array(data_VIC[-1] + pre_VIC)
data_VIC = np.concatenate((data_VIC,pre_VIC),axis= 0)

# %%
plt.plot(time_VIC,data_VIC,label = "VIC Predicted")
plt.plot(df_VIC["Close"], label = "VIC Actual")
plt.xlabel("Time")
plt.ylabel("Price")
plt.title("Close Stocks of VIC Chart")

plt.legend()

plt.xticks([])
plt.show()

# %% [markdown]
# ## Nhận xét tổng
# Với dữ liệu dạng chứng khoán ta không nên tin quá nhiều vào dữ liệu của `Model Machine Learning` hoặc `Deep Learning`
#
# Bởi vì giá trị chứng khoán biến động thất thường dựa vào thị trường, kinh tế, con người,...
#
# Với độ dữ liệu do `Model` cho ra chỉ là một con số ta tham khảo, và `accuracy` cũng chỉ mang tính chất tượng trưng, tuy nhiên khi ta có dữ liệu đủ lớn và thị trường không biến động quá nhiều thì các số liệu do `model Machine Learning` tương đối chính xác, là 1 nguồn đáng để tham khảo trước khi đầu tư.
